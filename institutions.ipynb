# %%
import pandas as pd
import matplotlib
from unidecode import unidecode
import requests
import json
import textdistance

# %%
edges = pd.read_csv('data/edges.csv')
row_filter = edges.academic_degree != 'mestrado'
col_filter = ['source_id_lattes', 'target_id_lattes', 'institution', 'conclusion_year', 'academic_degree']
df = edges.loc[row_filter, col_filter]
df
# Out:
#          source_id_lattes  target_id_lattes  \
# 3        3744329382300316       39015885890
# 4        4628431262205595       39015885890
# 5        8623798867256227       39015885890
# 10       2710474728753403      104116232000
# 11       9856154294275621      104116232000
# ...                   ...               ...
# 1633236  9979596352166630  9975608697544074
# 1633237  9999274930956418  9975992877773188
# 1633239  9986529923037985  9978858327330851
# 1633246  9991718680751230  9992478466506285
# 1633247  9991718680751230  9994632834495054
#
#                                                institution  conclusion_year  \
# 3                        instituto de física de são carlos             2015
# 4                              universidade federal do abc             2014
# 5           instituto de pesquisas energéticas e nucleares             2019
# 10                        universidade estadual de maringá             2016
# 11                        universidade estadual de maringá             2015
# ...                                                    ...              ...
# 1633236                      universidade federal de goiás             2021
# 1633237                          universidade de são paulo             2010
# 1633239                     universidade federal de viçosa             2009
# 1633246                          universidade de são paulo             2005
# 1633247  universidade estadual paulista júlio de mesqui...             1999
#
#         academic_degree
# 3         pos-doutorado
# 4             doutorado
# 5         pos-doutorado
# 10        pos-doutorado
# 11            doutorado
# ...                 ...
# 1633236       doutorado
# 1633237       doutorado
# 1633239       doutorado
# 1633246       doutorado
# 1633247       doutorado
#
# [482774 rows x 5 columns]

# %%
tmp = df.loc[df.academic_degree == 'doutorado', ['target_id_lattes', 'institution']]
tmp
# Out:
#          target_id_lattes                                        institution
# 4             39015885890                        universidade federal do abc
# 11           104116232000                   universidade estadual de maringá
# 19           111305956227                      universidade federal do ceará
# 31           174385402367                 universidade federal de são carlos
# 33           183606503103                      universidade federal de goiás
# ...                   ...                                                ...
# 1633236  9975608697544074                      universidade federal de goiás
# 1633237  9975992877773188                          universidade de são paulo
# 1633239  9978858327330851                     universidade federal de viçosa
# 1633246  9992478466506285                          universidade de são paulo
# 1633247  9994632834495054  universidade estadual paulista júlio de mesqui...
#
# [435170 rows x 2 columns]

# %%
df.rename(columns={'institution': 'target_institution'}, inplace=True)
tmp.rename(columns={'institution': 'source_institution', 'target_id_lattes': 'source_id_lattes'}, inplace=True)

# %%
institutions_raw = df.merge(tmp, on='source_id_lattes', how='left').dropna()
institutions_raw
# Out:
#         source_id_lattes  target_id_lattes  \
# 0       3744329382300316       39015885890
# 1       4628431262205595       39015885890
# 2       8623798867256227       39015885890
# 3       2710474728753403      104116232000
# 4       9856154294275621      104116232000
# ...                  ...               ...
# 502755  9979596352166630  9975608697544074
# 502756  9999274930956418  9975992877773188
# 502757  9986529923037985  9978858327330851
# 502758  9991718680751230  9992478466506285
# 502759  9991718680751230  9994632834495054
#
#                                        target_institution  conclusion_year  \
# 0                       instituto de física de são carlos             2015
# 1                             universidade federal do abc             2014
# 2          instituto de pesquisas energéticas e nucleares             2019
# 3                        universidade estadual de maringá             2016
# 4                        universidade estadual de maringá             2015
# ...                                                   ...              ...
# 502755                      universidade federal de goiás             2021
# 502756                          universidade de são paulo             2010
# 502757                     universidade federal de viçosa             2009
# 502758                          universidade de são paulo             2005
# 502759  universidade estadual paulista júlio de mesqui...             1999
#
#        academic_degree                                 source_institution
# 0        pos-doutorado                          universidade de são paulo
# 1            doutorado                          universidade de são paulo
# 2        pos-doutorado     instituto de pesquisas energéticas e nucleares
# 3        pos-doutorado                  universidade estadual de campinas
# 4            doutorado             universidade federal do rio de janeiro
# ...                ...                                                ...
# 502755       doutorado                           universidade de brasília
# 502756       doutorado             universidade federal do rio de janeiro
# 502757       doutorado  universidade estadual do norte fluminense darc...
# 502758       doutorado                          universidade de são paulo
# 502759       doutorado                          universidade de são paulo
#
# [429334 rows x 6 columns]

# %%
for year in range(1900, 2023, 5):
    row_filter = (institutions_raw.conclusion_year >= year) & (institutions_raw.conclusion_year <= year+4)
    institutions_raw.loc[row_filter, 'year_interval'] = f'{year}-{year+4}'
institutions_raw.year_interval
# Out:
# /tmp/ipykernel_3806/1334741872.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1900-1904' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   institutions_raw.loc[row_filter, 'year_interval'] = f'{year}-{year+4}'
# 0         2015-2019
# 1         2010-2014
# 2         2015-2019
# 3         2015-2019
# 4         2015-2019
#             ...
# 502755    2020-2024
# 502756    2010-2014
# 502757    2005-2009
# 502758    2005-2009
# 502759    1995-1999
# Name: year_interval, Length: 429334, dtype: object

# %%
dataviz = institutions_raw[['source_institution', 'target_institution']]

sourceviz = dataviz.groupby('source_institution').count().reset_index().rename(columns={
    'target_institution': 'weight',
    'source_institution': 'institution'
    })
targetviz = dataviz.groupby('target_institution').count().reset_index().rename(columns={
    'source_institution': 'weight',
    'target_institution': 'institution'
    })

# %%
sourceviz.groupby('weight').count().to_csv('source_weight_count')
targetviz.groupby('weight').count().to_csv('target_weight_count')

# %%
sourceviz = sourceviz[sourceviz.weight > 50]
targetviz = targetviz[targetviz.weight > 50]

# %%
source_institutions = list(sourceviz.institution.unique())
target_institutions = list(targetviz.institution.unique())
institutions = set(source_institutions + target_institutions)

# %%
name_table = pd.read_csv('jaccard.csv')
name_table.drop(columns='Unnamed: 0', inplace=True)
new_names = set(name_table.ror_name.to_list())
name_table
# Out:
#                                           acacia_name  \
# 0       universidad nacional de educación a distancia
# 1               escola de comunicações e artes da usp
# 2                             universidade de coimbra
# 3                     technical university of denmark
# 4    faculdade de engenharia da universidade do porto
# ..                                                ...
# 715                                université de caen
# 716                pontifícia universidade gregoriana
# 717                               university of tokyo
# 718                    technische universität münchen
# 719    escola superior de agricultura luiz de queiróz
#
#                                              ror_name
# 0       universidad nacional de educación a distancia
# 1               escola de comunicações e artes da usp
# 2                Hospitais da Universidade de Coimbra
# 3                     Technical University of Denmark
# 4    faculdade de engenharia da universidade do porto
# ..                                                ...
# 715                                université de caen
# 716                pontifícia universidade gregoriana
# 717                           The University of Tokyo
# 718                    technische universität münchen
# 719    escola superior de agricultura luiz de queiróz
#
# [720 rows x 2 columns]

# %%
institutions = new_names
name_table['distinct'] = 'distinct'
name_table.groupby('distinct').nunique()
# Out:
#           acacia_name  ror_name
# distinct
# distinct          720       694

# %%
name_table.drop(columns='distinct', inplace=True)
institutions_raw = institutions_raw.merge(
    name_table, left_on='source_institution', right_on='acacia_name'
    ).drop(
        columns=['acacia_name', 'source_institution']
        ).rename(columns={'ror_name': 'source_institution'})
institutions_raw = institutions_raw.merge(
    name_table, left_on='target_institution', right_on='acacia_name'
    ).drop(
        columns=['acacia_name', 'target_institution']
        ).rename(columns={'ror_name': 'target_institution'})
institutions_raw
# Out:
#         source_id_lattes  target_id_lattes  conclusion_year academic_degree  \
# 0       3744329382300316       39015885890             2015   pos-doutorado
# 1       8198392523716590    20850693692136             2003       doutorado
# 2       1426399772341383   191932527256862             2012       doutorado
# 3        194007981724312          10202349             2019   pos-doutorado
# 4        194007981724312          10256510             2012   pos-doutorado
# ...                  ...               ...              ...             ...
# 363761  5791603940369864          10627359             2006       doutorado
# 363762  5791603940369864          10637073             1998       doutorado
# 363763  5791603940369864          10637073             1998       doutorado
# 363764  5791603940369864          10650488             2001       doutorado
# 363765  5791603940369864          10650488             2001       doutorado
#
#        year_interval            source_institution  \
# 0          2015-2019     Universidade de São Paulo
# 1          2000-2004     Universidade de São Paulo
# 2          2010-2014     Universidade de São Paulo
# 3          2015-2019     Universidade de São Paulo
# 4          2010-2014     Universidade de São Paulo
# ...              ...                           ...
# 363761     2005-2009  Novosibirsk State University
# 363762     1995-1999  Novosibirsk State University
# 363763     1995-1999  Novosibirsk State University
# 363764     2000-2004  Novosibirsk State University
# 363765     2000-2004  Novosibirsk State University
#
#                        target_institution
# 0       instituto de física de são carlos
# 1       instituto de física de são carlos
# 2       instituto de física de são carlos
# 3       instituto de física de são carlos
# 4       instituto de física de são carlos
# ...                                   ...
# 363761       Novosibirsk State University
# 363762       Novosibirsk State University
# 363763       Novosibirsk State University
# 363764       Novosibirsk State University
# 363765       Novosibirsk State University
#
# [363766 rows x 7 columns]

# %%
# cols = ['institution', 'distancia', 'orientacoes', 'orientadores', 'orientandos', 'institutos', 'year_interval', 'academic_degree']
node_tree_metrics = pd.DataFrame()
edge_tree_metrics = pd.DataFrame()

node_metrics = pd.DataFrame()


for institution in institutions:
    visited_academics = set()
    seeds =  set(institutions_raw[institutions_raw.source_institution == institution].source_id_lattes)
    distance = 1
    
    
    while len(seeds) > 0:
        visited_academics.update(seeds)
        influence_df = institutions_raw[institutions_raw.source_id_lattes.isin(seeds)]

        node_tree_metrics_tmp = influence_df.groupby(['academic_degree', 'year_interval']).agg(
            orientacoes=('source_id_lattes', 'count'),
            orientadores=('source_id_lattes', 'nunique'),
            orientandos=('target_id_lattes', 'nunique'),
            institutos_fonte=('source_institution', 'nunique'),
            institutos_alvo=('target_institution', 'nunique'),
            primeira_ocorrencia=('conclusion_year', 'min')
        ).reset_index()
        
        node_tree_metrics_tmp['reference_institution'] = institution
        node_tree_metrics_tmp['distancia'] = distance
        node_tree_metrics = pd.concat([node_tree_metrics, node_tree_metrics_tmp])

        edge_tree_metrics_tmp = influence_df.groupby(
            ['source_institution', 'target_institution', 'academic_degree', 'year_interval']
            ).agg(
            orientacoes=('source_id_lattes', 'count'),
            orientadores=('source_id_lattes', 'nunique'),
            orientandos=('target_id_lattes', 'nunique'),
            primeira_ocorrencia=('conclusion_year', 'min')
        ).reset_index()

        edge_tree_metrics_tmp['reference_institution'] = institution
        edge_tree_metrics_tmp['distancia'] = distance
        edge_tree_metrics = pd.concat([edge_tree_metrics, edge_tree_metrics_tmp])


        distance += 1
        seeds = set(influence_df.target_id_lattes) - visited_academics
node_tree_metrics.sort_values(['reference_institution', 'year_interval','distancia'])

edge_tree_metrics.rename(columns={
    'source_institution': 'Source',
    'target_institution': 'Target'
}, inplace=True)
node_tree_metrics.to_csv('results/intervaled/search-tree-nodes.csv', index=False)
edge_tree_metrics.to_csv('results/intervaled/search-tree-edges.csv', index=False)

# %%
node_tree_metrics
# Out:
#    academic_degree year_interval  orientacoes  orientadores  orientandos  \
# 0        doutorado     1990-1994            1             1            1
# 1        doutorado     2005-2009            1             1            1
# 2        doutorado     2010-2014            5             2            5
# 3        doutorado     2015-2019            5             2            4
# 4        doutorado     2020-2024            1             1            1
# ..             ...           ...          ...           ...          ...
# 0        doutorado     2015-2019           10             4           10
# 1        doutorado     2020-2024            5             4            5
# 2    pos-doutorado     2005-2009            1             1            1
# 3    pos-doutorado     2010-2014            4             1            4
# 4    pos-doutorado     2015-2019            6             5            6
#
#     institutos_fonte  institutos_alvo  primeira_ocorrencia  \
# 0                  1                1                 1994
# 1                  1                1                 2006
# 2                  1                3                 2010
# 3                  2                2                 2015
# 4                  1                1                 2022
# ..               ...              ...                  ...
# 0                  3                5                 2015
# 1                  3                3                 2020
# 2                  1                1                 2007
# 3                  1                1                 2010
# 4                  4                4                 2015
#
#                             reference_institution  distancia
# 0   universidad nacional de educación a distancia          1
# 1   universidad nacional de educación a distancia          1
# 2   universidad nacional de educación a distancia          1
# 3   universidad nacional de educación a distancia          1
# 4   universidad nacional de educación a distancia          1
# ..                                            ...        ...
# 0                          University of Stirling          2
# 1                          University of Stirling          2
# 2                          University of Stirling          2
# 3                          University of Stirling          2
# 4                          University of Stirling          2
#
# [13266 rows x 10 columns]

# %%
edge_tree_metrics
# Out:
#                                            Source  \
# 0          Universidade Estadual Paulista (Unesp)
# 1   universidad nacional de educación a distancia
# 2   universidad nacional de educación a distancia
# 3   universidad nacional de educación a distancia
# 4   universidad nacional de educación a distancia
# ..                                            ...
# 9                universidade estadual de maringá
# 10                   universidade federal do pará
# 11                   universidade federal do pará
# 12                   universidade federal do pará
# 13                   universidade federal do pará
#
#                                     Target academic_degree year_interval  \
# 0   Universidade Estadual Paulista (Unesp)       doutorado     2015-2019
# 1         Universidad Autónoma de Asunción       doutorado     2010-2014
# 2         Universidad Autónoma de Asunción       doutorado     2015-2019
# 3         Universidad Autónoma de Asunción       doutorado     2020-2024
# 4        Universidad Complutense de Madrid       doutorado     1990-1994
# ..                                     ...             ...           ...
# 9         universidade estadual de maringá   pos-doutorado     2015-2019
# 10            Museu Paraense Emílio Goeldi       doutorado     2020-2024
# 11            Museu Paraense Emílio Goeldi   pos-doutorado     2015-2019
# 12        universidade federal do amazonas       doutorado     2015-2019
# 13            universidade federal do pará       doutorado     2015-2019
#
#     orientacoes  orientadores  orientandos  primeira_ocorrencia  \
# 0             1             1            1                 2018
# 1             3             1            3                 2010
# 2             3             1            3                 2015
# 3             1             1            1                 2022
# 4             1             1            1                 1994
# ..          ...           ...          ...                  ...
# 9             2             1            2                 2015
# 10            1             1            1                 2020
# 11            1             1            1                 2019
# 12            2             1            2                 2016
# 13            2             1            2                 2016
#
#                             reference_institution  distancia
# 0   universidad nacional de educación a distancia          1
# 1   universidad nacional de educación a distancia          1
# 2   universidad nacional de educación a distancia          1
# 3   universidad nacional de educación a distancia          1
# 4   universidad nacional de educación a distancia          1
# ..                                            ...        ...
# 9                          University of Stirling          2
# 10                         University of Stirling          2
# 11                         University of Stirling          2
# 12                         University of Stirling          2
# 13                         University of Stirling          2
#
# [104234 rows x 10 columns]

# %%
# cols = ['institution', 'distancia', 'orientacoes', 'orientadores', 'orientandos', 'institutos', 'year_interval', 'academic_degree']
node_tree_metrics = pd.DataFrame()
edge_tree_metrics = pd.DataFrame()


for institution in institutions:
    visited_academics = set()
    seeds =  set(institutions_raw[institutions_raw.source_institution == institution].source_id_lattes)
    distance = 1
    
    
    while len(seeds) > 0:
        visited_academics.update(seeds)
        influence_df = institutions_raw[institutions_raw.source_id_lattes.isin(seeds)]
        node_tree_metrics_tmp = influence_df.drop(columns='year_interval').groupby(['academic_degree']).agg(
            orientacoes=('source_id_lattes', 'count'),
            orientadores=('source_id_lattes', 'nunique'),
            orientandos=('target_id_lattes', 'nunique'),
            institutos_fonte=('source_institution', 'nunique'),
            institutos_alvo=('target_institution', 'nunique'),
            primeira_ocorrencia=('conclusion_year', 'min')
        ).reset_index()
        
        node_tree_metrics_tmp['reference_institution'] = institution
        node_tree_metrics_tmp['distancia'] = distance
        node_tree_metrics = pd.concat([node_tree_metrics, node_tree_metrics_tmp])

        edge_tree_metrics_tmp = influence_df.drop(columns='year_interval').groupby(
            ['source_institution', 'target_institution', 'academic_degree']
            ).agg(
            orientacoes=('source_id_lattes', 'count'),
            orientadores=('source_id_lattes', 'nunique'),
            orientandos=('target_id_lattes', 'nunique'),
            primeira_ocorrencia=('conclusion_year', 'min')
        ).reset_index()

        edge_tree_metrics_tmp['reference_institution'] = institution
        edge_tree_metrics_tmp['distancia'] = distance
        edge_tree_metrics = pd.concat([edge_tree_metrics, edge_tree_metrics_tmp])


        distance += 1
        seeds = set(influence_df.target_id_lattes) - visited_academics
node_tree_metrics.sort_values(['reference_institution','distancia'])

edge_tree_metrics.rename(columns={
    'source_institution': 'Source',
    'target_institution': 'Target'
}, inplace=True)

node_tree_metrics.to_csv('results/search-tree-nodes.csv', index=False)
edge_tree_metrics.to_csv('results/search-tree-edges.csv', index=False)

# %%
node_tree_metrics
# Out:
#    academic_degree  orientacoes  orientadores  orientandos  institutos_fonte  \
# 0        doutorado           13             4           12                 2
# 0        doutorado            1             1            1                 1
# 0        doutorado           30             2           30                 1
# 0        doutorado           11             2            6                 2
# 0        doutorado           72             5           66                 2
# ..             ...          ...           ...          ...               ...
# 0        doutorado            8             2            8                 2
# 0        doutorado           83            11           83                 1
# 1    pos-doutorado           19             5           19                 1
# 0        doutorado           15             6           15                 4
# 1    pos-doutorado           11             6           11                 5
#
#     institutos_alvo  primeira_ocorrencia  \
# 0                 5                 1994
# 0                 1                 2015
# 0                 5                 2010
# 0                 1                 2012
# 0                 6                 2003
# ..              ...                  ...
# 0                 2                 2016
# 0                10                 1999
# 1                 7                 2004
# 0                 7                 2015
# 1                 5                 2007
#
#                             reference_institution  distancia
# 0   universidad nacional de educación a distancia          1
# 0   universidad nacional de educación a distancia          2
# 0                          universiadad del norte          1
# 0                          universiadad del norte          2
# 0                            universität dortmund          1
# ..                                            ...        ...
# 0    Universidad de Ciencias Médicas de la Habana          2
# 0                          University of Stirling          1
# 1                          University of Stirling          1
# 0                          University of Stirling          2
# 1                          University of Stirling          2
#
# [3268 rows x 9 columns]

# %%
edge_tree_metrics
# Out:
#                                            Source  \
# 0          Universidade Estadual Paulista (Unesp)
# 1   universidad nacional de educación a distancia
# 2   universidad nacional de educación a distancia
# 3   universidad nacional de educación a distancia
# 4   universidad nacional de educación a distancia
# ..                                            ...
# 7                universidade estadual de maringá
# 8                    universidade federal do pará
# 9                    universidade federal do pará
# 10                   universidade federal do pará
# 11                   universidade federal do pará
#
#                                     Target academic_degree  orientacoes  \
# 0   Universidade Estadual Paulista (Unesp)       doutorado            1
# 1         Universidad Autónoma de Asunción       doutorado            7
# 2        Universidad Complutense de Madrid       doutorado            2
# 3   Universidade Estadual Paulista (Unesp)       doutorado            1
# 4                   universidad de granada       doutorado            1
# ..                                     ...             ...          ...
# 7         universidade estadual de maringá   pos-doutorado            6
# 8             Museu Paraense Emílio Goeldi       doutorado            1
# 9             Museu Paraense Emílio Goeldi   pos-doutorado            1
# 10        universidade federal do amazonas       doutorado            2
# 11            universidade federal do pará       doutorado            2
#
#     orientadores  orientandos  primeira_ocorrencia  \
# 0              1            1                 2018
# 1              1            7                 2010
# 2              1            2                 1994
# 3              1            1                 2018
# 4              1            1                 2013
# ..           ...          ...                  ...
# 7              1            6                 2010
# 8              1            1                 2020
# 9              1            1                 2019
# 10             1            2                 2016
# 11             1            2                 2016
#
#                             reference_institution  distancia
# 0   universidad nacional de educación a distancia          1
# 1   universidad nacional de educación a distancia          1
# 2   universidad nacional de educación a distancia          1
# 3   universidad nacional de educación a distancia          1
# 4   universidad nacional de educación a distancia          1
# ..                                            ...        ...
# 7                          University of Stirling          2
# 8                          University of Stirling          2
# 9                          University of Stirling          2
# 10                         University of Stirling          2
# 11                         University of Stirling          2
#
# [50612 rows x 9 columns]

# %%
filtered_df = institutions_raw[
    institutions_raw.source_institution.isin(institutions) & institutions_raw.target_institution.isin(institutions)
]
edge_metrics = filtered_df.drop(columns='year_interval').groupby(['source_institution', 'target_institution', 'academic_degree']).agg(
    orientacoes=('source_id_lattes', 'count'),
    orientadores=('source_id_lattes', 'nunique'),
    orientandos=('target_id_lattes', 'nunique'),
    primeira_ocorrencia=('conclusion_year', 'min')
).reset_index().dropna(subset=['source_institution', 'target_institution'])
edge_metrics.rename(columns={
    'source_institution': 'Source',
    'target_institution': 'Target'
}, inplace=True)
edge_metrics.to_csv('results/edges.csv', index=False)
edge_metrics
# Out:
#                                                Source  \
# 0      ARC Centre of Excellence for the Digital Child
# 1      ARC Centre of Excellence for the Digital Child
# 2      ARC Centre of Excellence for the Digital Child
# 3      ARC Centre of Excellence for the Digital Child
# 4      ARC Centre of Excellence for the Digital Child
# ...                                               ...
# 15805    école des hautes études en sciences sociales
# 15806    école des hautes études en sciences sociales
# 15807    école des hautes études en sciences sociales
# 15808    école des hautes études en sciences sociales
# 15809    école des hautes études en sciences sociales
#
#                                                   Target academic_degree  \
# 0         ARC Centre of Excellence for the Digital Child       doutorado
# 1         ARC Centre of Excellence for the Digital Child   pos-doutorado
# 2                       Escola Nacional de Saúde Pública       doutorado
# 3      Hospital de Clínicas Universidade Federal do P...       doutorado
# 4      Hospital de Clínicas Universidade Federal do P...   pos-doutorado
# ...                                                  ...             ...
# 15805                universidade metodista de são paulo       doutorado
# 15806                        université de franche comté       doutorado
# 15807                      université libre de bruxelles       doutorado
# 15808          université paris est créteil val de marne       doutorado
# 15809       école des hautes études en sciences sociales       doutorado
#
#        orientacoes  orientadores  orientandos  primeira_ocorrencia
# 0                7             1            7                 1996
# 1               10             1           10                 2003
# 2                2             1            2                 2005
# 3               12             1           12                 2004
# 4                2             1            2                 2010
# ...            ...           ...          ...                  ...
# 15805            2             1            2                 1998
# 15806            1             1            1                 2019
# 15807            1             1            1                 2011
# 15808            1             1            1                 2013
# 15809            3             3            3                 2003
#
# [15810 rows x 7 columns]

# %%
filtered_df = institutions_raw[
    institutions_raw.source_institution.isin(institutions) & institutions_raw.target_institution.isin(institutions)
]
edge_metrics = filtered_df.groupby(['source_institution', 'target_institution', 'academic_degree', 'year_interval']).agg(
    orientacoes=('source_id_lattes', 'count'),
    orientadores=('source_id_lattes', 'nunique'),
    orientandos=('target_id_lattes', 'nunique'),
    primeira_ocorrencia=('conclusion_year', 'min')
).reset_index().dropna(subset=['source_institution', 'target_institution'])
edge_metrics.sort_values(['year_interval'])
edge_metrics.rename(columns={
    'source_institution': 'Source',
    'target_institution': 'Target'
}, inplace=True)
edge_metrics.to_csv('results/intervaled/edges.csv', index=False)
edge_metrics
# Out:
#                                                Source  \
# 0      ARC Centre of Excellence for the Digital Child
# 1      ARC Centre of Excellence for the Digital Child
# 2      ARC Centre of Excellence for the Digital Child
# 3      ARC Centre of Excellence for the Digital Child
# 4      ARC Centre of Excellence for the Digital Child
# ...                                               ...
# 38975    école des hautes études en sciences sociales
# 38976    école des hautes études en sciences sociales
# 38977    école des hautes études en sciences sociales
# 38978    école des hautes études en sciences sociales
# 38979    école des hautes études en sciences sociales
#
#                                                Target academic_degree  \
# 0      ARC Centre of Excellence for the Digital Child       doutorado
# 1      ARC Centre of Excellence for the Digital Child       doutorado
# 2      ARC Centre of Excellence for the Digital Child   pos-doutorado
# 3      ARC Centre of Excellence for the Digital Child   pos-doutorado
# 4      ARC Centre of Excellence for the Digital Child   pos-doutorado
# ...                                               ...             ...
# 38975                   université libre de bruxelles       doutorado
# 38976       université paris est créteil val de marne       doutorado
# 38977    école des hautes études en sciences sociales       doutorado
# 38978    école des hautes études en sciences sociales       doutorado
# 38979    école des hautes études en sciences sociales       doutorado
#
#       year_interval  orientacoes  orientadores  orientandos  \
# 0         1995-1999            3             1            3
# 1         2000-2004            4             1            4
# 2         2000-2004            3             1            3
# 3         2005-2009            3             1            3
# 4         2010-2014            4             1            4
# ...             ...          ...           ...          ...
# 38975     2010-2014            1             1            1
# 38976     2010-2014            1             1            1
# 38977     2000-2004            1             1            1
# 38978     2010-2014            1             1            1
# 38979     2015-2019            1             1            1
#
#        primeira_ocorrencia
# 0                     1996
# 1                     2000
# 2                     2003
# 3                     2005
# 4                     2011
# ...                    ...
# 38975                 2011
# 38976                 2013
# 38977                 2003
# 38978                 2014
# 38979                 2017
#
# [38980 rows x 8 columns]

# %%
def query_ror(name):
    query_name = unidecode(name).replace(' ', '%20')
    query_str = f'https://api.ror.org/organizations?query.advanced=name:{query_name}'
    results = requests.get(query_str)
    std_name = json.loads(results.text)
    if len(std_name['items']) == 0:
        return name
    match_val = 0
    idx = 0
    for i in range(int(std_name['number_of_results'])):
        if len(std_name['items'][i:]) < 1:
            continue
        tmp = textdistance.levenshtein.similarity(std_name['items'][i]['name'], name)
        if match_val < tmp:
            match_val = tmp
            idx = i
    return std_name['items'][idx]['name']
# name_table = pd.DataFrame(data={'acacia_name': list(institutions)})
# name_table['ror_name'] = name_table.acacia_name.apply(query_ror)
# name_table
# name_table.to_csv('levenshtein.csv')

# %%
name_table['distinct'] = 'distinct'
name_table.groupby('distinct').nunique()
# Out:
#           acacia_name  ror_name
# distinct
# distinct          720       694

# %%
src_nodes = institutions_raw.groupby(['source_institution', 'academic_degree', 'year_interval']).agg(
    orientacoes_externas=('source_id_lattes','count'),
    orientadores_externos=('source_id_lattes', 'nunique'),
    orientandos_externos=('target_id_lattes', 'nunique'),
    instituicoes_alvo=('target_institution', 'nunique'),
    primeira_ocorrencia_externa=('conclusion_year', 'min')
).reset_index().rename(columns={'source_institution': 'institution'})
tgt_nodes = institutions_raw.groupby(['target_institution', 'academic_degree', 'year_interval']).agg(
    orientacoes_internas=('source_id_lattes','count'),
    orientadores_internos=('source_id_lattes', 'nunique'),
    orientandos_internos=('target_id_lattes', 'nunique'),
    instituicoes_fonte=('source_institution', 'nunique'),
    primeira_ocorrencia_interna=('conclusion_year', 'min')
).reset_index().rename(columns={'target_institution': 'institution'})
tree = pd.read_csv('results/intervaled/search-tree-nodes.csv')
tree = tree[['distancia', 'reference_institution', 'year_interval', 'academic_degree']]
tree = tree.groupby(['distancia', 'reference_institution', 'year_interval', 'academic_degree']).max().reset_index()
tree = tree.rename({'reference_institution': 'institution'})
nodes = tgt_nodes.merge(src_nodes, on=['institution', 'academic_degree', 'year_interval'], how='outer')
nodes = nodes.merge(tree, on=['academic_degree', 'institution', 'year_interval'], how='left')
nodes = nodes.fillna(0)
cols = [col for col in nodes.columns if col not in ['academic_degree', 'institution', 'year_interval']]
nodes[cols] = nodes[cols].astype(int)
nodes.to_csv('results/intervaled/nodes.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3806/164504161.py in ?()
#      16 tree = tree[['distancia', 'reference_institution', 'year_interval', 'academic_degree']]
#      17 tree = tree.groupby(['distancia', 'reference_institution', 'year_interval', 'academic_degree']).max().reset_index()
#      18 tree = tree.rename({'reference_institution': 'institution'})
#      19 nodes = tgt_nodes.merge(src_nodes, on=['institution', 'academic_degree', 'year_interval'], how='outer')
# ---> 20 nodes = nodes.merge(tree, on=['academic_degree', 'institution', 'year_interval'], how='left')
#      21 nodes = nodes.fillna(0)
#      22 cols = [col for col in nodes.columns if col not in ['academic_degree', 'institution', 'year_interval']]
#      23 nodes[cols] = nodes[cols].astype(int)
#
# ~/summag/.gen/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10486         validate: MergeValidate | None = None,
#   10487     ) -> DataFrame:
#   10488         from pandas.core.reshape.merge import merge
#   10489
# > 10490         return merge(
#   10491             self,
#   10492             right,
#   10493             how=how,
#
# ~/summag/.gen/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# ~/summag/.gen/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/summag/.gen/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1265                         # Then we're either Hashable or a wrong-length arraylike,
#    1266                         #  the latter of which will raise
#    1267                         rk = cast(Hashable, rk)
#    1268                         if rk is not None:
# -> 1269                             right_keys.append(right._get_label_or_level_values(rk))
#    1270                         else:
#    1271                             # work-around for merge_asof(right_index=True)
#    1272                             right_keys.append(right.index._values)
#
# ~/summag/.gen/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'institution'

# %%
src_nodes = institutions_raw.drop(columns='year_interval').groupby(['source_institution', 'academic_degree']).agg(
    orientacoes_externas=('source_id_lattes','count'),
    orientadores_externos=('source_id_lattes', 'nunique'),
    orientandos_externos=('target_id_lattes', 'nunique'),
    instituicoes_alvo=('target_institution', 'nunique'),
    primeira_ocorrencia_externa=('conclusion_year', 'min')
).reset_index().rename(columns={'source_institution': 'institution'})
tgt_nodes = institutions_raw.drop(columns='year_interval').groupby(['target_institution', 'academic_degree']).agg(
    orientacoes_internas=('source_id_lattes','count'),
    orientadores_internos=('source_id_lattes', 'nunique'),
    orientandos_internos=('target_id_lattes', 'nunique'),
    instituicoes_fonte=('source_institution', 'nunique'),
    primeira_ocorrencia_interna=('conclusion_year', 'min')
).reset_index().rename(columns={'target_institution': 'institution'})
tree = pd.read_csv('results/search-tree-nodes.csv')
tree = tree[['distancia', 'reference_institution', 'academic_degree']]
tree = tree.groupby(['distancia', 'reference_institution', 'academic_degree']).max().reset_index()
tree = tree.rename({'reference_institution': 'institution'})
nodes = tgt_nodes.merge(src_nodes, on=['institution', 'academic_degree'], how='outer')
nodes = nodes.merge(tree, on=['academic_degree', 'institution'], how='left')nodes = nodes.fillna(0)
cols = [col for col in nodes.columns if col not in ['academic_degree', 'institution']]
nodes[cols] = nodes[cols].astype(int)
nodes.to_csv('results/intervaled/nodes.csv', index=False)
